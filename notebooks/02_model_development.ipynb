# %% [markdown]
# # 02 Model Development
#
# Inspect validation metrics from HuggingFace transfer learning. Change params.yaml and run dvc repro train to compare experiments. Choose by validation F1 before looking at test metrics.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))

import mlflow
import json

mlflow.set_tracking_uri('sqlite:///' + (ROOT / 'mlflow.db').as_posix())
experiment = mlflow.get_experiment_by_name('imdb-transfer-learning')
runs = mlflow.search_runs(experiment_ids=[experiment.experiment_id], order_by=['metrics.best_validation_f1 DESC'])
runs[['run_id', 'params.learning_rate', 'params.freeze_encoder', 'metrics.best_validation_f1']]
