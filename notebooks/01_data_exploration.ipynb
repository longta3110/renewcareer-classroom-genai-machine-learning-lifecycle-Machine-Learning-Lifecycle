# %% [markdown]
# # 01 Data Exploration
#
# Explore the real IMDB training partition. Run the download and DVC preparation stages first. Test reviews are reserved for final evaluation.

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))

import pandas as pd

df = pd.read_csv(ROOT / 'data/processed/imdb/train.csv')
df.head()

# %%
from src.explore import main
from IPython.display import Image, display
main()
display(Image(filename=str(ROOT / 'reports/data_exploration.png')))
df['label'].value_counts()
